# %% [markdown]
# (Note! Feel free to change up anything, this is just a suggested structure.)
#
# (Kaggle group name and members need to be mentioned somewhere in the report but can be moved to end of notebook if that's better.)
#
# Group name:
#
# Group members: (let's add these at the final stage)

# %% [markdown]
# # Title

# %% [markdown]
# ## Introduction
#
# - define the task (1 paragraph)
# - brief description of NPF (1 paragraph)

# %% [markdown]
# ## Data
#
# TODO:
# - SMEAR II & Hyytiälä (1 paragraph)
# - description of the datasets (1–2 paragraphs)
#   - classified training data, unclassified test data
#   - data variables
#   - classification scheme (event types) (see *Dal Maso et al 2005*)
#   - preprocessed to some degree already (e.g. no missing data)
#
# The classification scheme is based on the event types defined by Dal Maso et al. (2005):
# - Class I: Days when the growth and formation rate could be determined with a good confidence level
#   - Class Ia: Very clear and strong particle formation events, with little or no pre-existing particles obscuring the newly formed mode
#   - Class Ib: The rest of Class I events
# - Class II: Days where the derivation of these parameters was not possible or the accuracy of the results was questionable
# - Nonevent

# %% [markdown]
# (It might besensible to split the methods section into a theory part and practical part e.g. "Computational methods" and "Methods" (latter needs better name). For each method, we should provide enough definition, include relevant formulas, etc.)
#
# ## Methods
#
# ### Data Preprocessing
#
# - describe preprocessing steps
#   - regularization (for some methods)
#
# ### Exploratory Data Analysis
#
# - what we know based on the data description alone (and did that influence our approach)
# - for each approach, explain reasoning for selecting the method in question, steps taken, results (add visualization if relevant) and insights gained
#     - clustering methods
#     - PCA
#
# ### Feature Selection
#
# - which features we selected and why
#
# ### Algorithm Selection
#
# - splitting into training and evaluation data
# - for each approach, explain reasoning for selecting the method in question, steps taken, results (add visualization if relevant) and insights gained
#
# #### Logistic Regression
#
#
# ### Model Training
#
#
# ### Model Evaluation and Tuning

# %% [markdown]
# ## Results

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ## References
#
# - Dal Maso, M. et al. (2005) Formation and growth of fresh atmospheric aerosols: eight years of aerosol size distribution data from SMEAR II, Hyytiaelae, Finland. Boreal environment research. 10 (5), 323–336.
